# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df_03클래식 = pd.read_csv("1_sample_time/2003_클래식.csv")
df_04이터널선샤인 = pd.read_csv("1_sample_time/2004_이터널_선샤인.csv")
df_04태극기휘날리며 = pd.read_csv("1_sample_time/2004_태극기_휘날리며.csv")
df_05왕의남자 = pd.read_csv("1_sample_time/2005_왕의_남자.csv")
df_05찰리와초콜릿공장 = pd.read_csv("1_sample_time/2005_찰리와_초콜릿_공장.csv")

df_06라디오스타 = pd.read_csv("1_sample_time/2006_라디오스타.csv")
df_06미녀는괴로워 = pd.read_csv("1_sample_time/2006_미녀는_괴로워.csv")
df_071번가의기적 = pd.read_csv("1_sample_time/2007_1번가의_기적.csv")
df_07밀양 = pd.read_csv("1_sample_time/2007_밀양.csv")

df_08다크나이트 = pd.read_csv("1_sample_time/2008_다크나이트.csv")
df_08말할수없는비밀 = pd.read_csv("1_sample_time/2008_말할_수_없는_비밀.csv")
df_097급공무원 = pd.read_csv("1_sample_time/2009_7급공무원.csv")
df_09전우치 = pd.read_csv("1_sample_time/2009_전우치.csv")

df_09전우치
# Out:
#            댓글번호              작성일자  \
# 0       7344247  2013.03.13 13:51
# 1       7365512  2013.03.19 16:28
# 2       7226353  2013.02.05 00:31
# 3       7959988  2013.09.08 20:48
# 4       7203345  2013.01.31 15:39
# ...         ...               ...
# 19815  17681548  2021.08.31 21:37
# 19816  15352589  2019.03.02 22:45
# 19817  10335633  2015.09.16 21:34
# 19818  17041091  2020.08.08 17:56
# 19819  16691431  2020.02.08 08:34
#
#                                                       댓글  평점  관람여부  스포여부  \
# 0      강동원이란 배우에게 빠지게 된 계기가 된 영화전우치의 자유롭고 발랄발랄한 모습이 보...  10     0     0
# 1                        이거 진짜 와...대박 강동원씨 언기도잘하고 언굴도..헿  10     0     0
# 2                                       전우치역할만큼은 강동원이 최고   5     0     0
# 3      안티도 없고 알바도 없는 3년지난 지금 평점남깁니다.  이영화 만드시는데 고생하신분...  10     0     0
# 4              정말 재미있었고 즐기면서 봤다히어로 영화의 명작이제 ㅋㅋ너무 너무 짱이었다  10     0     0
# ...                                                  ...  ..   ...   ...
# ...

# %% [markdown]
# 영화이름 넣기

# %%
df_03클래식["영화제목"] = "클래식"

df_04이터널선샤인["영화제목"] = "이터널_선샤인"
df_04태극기휘날리며["영화제목"] = "태극기_휘날리며"
df_05왕의남자["영화제목"] = "왕의_남자"
df_05찰리와초콜릿공장["영화제목"] = "찰리와_초콜릿_공장"

df_06라디오스타["영화제목"] = "라디오스타"
df_06미녀는괴로워["영화제목"] = "미녀는_괴로워"
df_071번가의기적["영화제목"] = "1번가의_기적"
df_07밀양["영화제목"] = "밀양"

df_08다크나이트["영화제목"] = "다크나이트"
df_08말할수없는비밀["영화제목"] = "말할_수_없는_비밀"
df_097급공무원["영화제목"] = "7급공무원"
df_09전우치["영화제목"] = "전우치"

# %%
df_04이터널선샤인.drop(columns='Unnamed: 0', inplace = True)

# %%
df_04태극기휘날리며.drop(columns='Unnamed: 0', inplace = True)
df_04태극기휘날리며
# Out:
#            댓글번호              작성일자  \
# 0       7641243  2013.06.15 06:06
# 1       7586730  2013.06.05 23:51
# 2       7687574  2013.06.28 21:32
# 3       7684885  2013.06.27 23:16
# 4       7615983  2013.06.09 04:45
# ...         ...               ...
# 10854   7537741  2013.05.18 11:26
# 10855  14352659  2018.07.26 15:28
# 10856  16763684  2020.03.07 04:22
# 10857  15275247  2019.02.14 13:36
# 10858  14480724  2018.08.15 12:39
#
#                                                       댓글  평점  관람여부  스포여부  \
# 0      중학교때 처음보고 제일 많이 울었던 영화다. 9년이 지나고 대학을 졸업한 지금, 갑...  10     0     0
# 1                                           우리나라 영화 top5  10     0     0
# 2                                      말이필요없는 대작이다......  10     0     0
# 3                                              감동의 대작 ㅠㅠ  10     0     0
# 4                           언제봐도 최고 요즘 천만관객 영화보다 훨씬 뛰어나다  10     0     0
# ...                                                  ...  ..   ...   ...
# ...

# %%
df_05왕의남자.drop(columns='Unnamed: 0', inplace = True)
df_05찰리와초콜릿공장.drop(columns='Unnamed: 0', inplace = True)

df_06라디오스타.drop(columns='Unnamed: 0', inplace = True)
df_06미녀는괴로워.drop(columns='Unnamed: 0', inplace = True)
df_071번가의기적.drop(columns='Unnamed: 0', inplace = True)
df_07밀양.drop(columns='Unnamed: 0', inplace = True)

df_08다크나이트.drop(columns='Unnamed: 0', inplace = True)
df_08말할수없는비밀.drop(columns='Unnamed: 0', inplace = True)
df_097급공무원.drop(columns='Unnamed: 0', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/qw/j72d9nwn5dq0vxtqtw2bbtnh0000gp/T/ipykernel_5688/3914652520.py in <module>
#       8
#       9 df_08다크나이트.drop(columns='Unnamed: 0', inplace = True)
# ---> 10 df_08말할수없는비밀.drop(columns='Unnamed: 0', inplace = True)
#      11 df_097급공무원.drop(columns='Unnamed: 0', inplace = True)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
# ...

# %%
df_03클래식.to_csv("1_sample_time/2003_클래식.csv", index=False)
df_04이터널선샤인.to_csv("1_sample_time/2004_이터널_선샤인.csv", index=False)
df_04태극기휘날리며.to_csv("1_sample_time/2004_태극기_휘날리며.csv", index=False)
df_05왕의남자.to_csv("1_sample_time/2005_왕의_남자.csv", index=False)
df_05찰리와초콜릿공장.to_csv("1_sample_time/2005_찰리와_초콜릿_공장.csv", index=False)

df_06라디오스타.to_csv("1_sample_time/2006_라디오스타.csv", index=False)
df_06미녀는괴로워.to_csv("1_sample_time/2006_미녀는_괴로워.csv", index=False)
df_071번가의기적.to_csv("1_sample_time/2007_1번가의_기적.csv", index=False)
df_07밀양.to_csv("1_sample_time/2007_밀양.csv", index=False)

df_08다크나이트.to_csv("1_sample_time/2008_다크나이트.csv", index=False)
df_08말할수없는비밀.to_csv("1_sample_time/2008_말할_수_없는_비밀.csv", index=False)
df_097급공무원.to_csv("1_sample_time/2009_7급공무원.csv", index=False)
df_09전우치.to_csv("1_sample_time/2009_전우치.csv", index=False)

# %%
import datetime
import time

# %%
df_03클래식 = pd.read_csv("1_sample_time/2003_클래식.csv")
df_04이터널선샤인 = pd.read_csv("1_sample_time/2004_이터널_선샤인.csv")
df_04태극기휘날리며 = pd.read_csv("1_sample_time/2004_태극기_휘날리며.csv")
df_05왕의남자 = pd.read_csv("1_sample_time/2005_왕의_남자.csv")
df_05찰리와초콜릿공장 = pd.read_csv("1_sample_time/2005_찰리와_초콜릿_공장.csv")

df_06라디오스타 = pd.read_csv("1_sample_time/2006_라디오스타.csv")
df_06미녀는괴로워 = pd.read_csv("1_sample_time/2006_미녀는_괴로워.csv")
df_071번가의기적 = pd.read_csv("1_sample_time/2007_1번가의_기적.csv")
df_07밀양 = pd.read_csv("1_sample_time/2007_밀양.csv")

df_08다크나이트 = pd.read_csv("1_sample_time/2008_다크나이트.csv")
df_08말할수없는비밀 = pd.read_csv("1_sample_time/2008_말할_수_없는_비밀.csv")
df_097급공무원 = pd.read_csv("1_sample_time/2009_7급공무원.csv")
df_09전우치 = pd.read_csv("1_sample_time/2009_전우치.csv")

df_09전우치
# Out:
#            댓글번호              작성일자  \
# 0       7344247  2013.03.13 13:51
# 1       7365512  2013.03.19 16:28
# 2       7226353  2013.02.05 00:31
# 3       7959988  2013.09.08 20:48
# 4       7203345  2013.01.31 15:39
# ...         ...               ...
# 19815  17681548  2021.08.31 21:37
# 19816  15352589  2019.03.02 22:45
# 19817  10335633  2015.09.16 21:34
# 19818  17041091  2020.08.08 17:56
# 19819  16691431  2020.02.08 08:34
#
#                                                       댓글  평점  관람여부  스포여부  \
# 0      강동원이란 배우에게 빠지게 된 계기가 된 영화전우치의 자유롭고 발랄발랄한 모습이 보...  10     0     0
# 1                        이거 진짜 와...대박 강동원씨 언기도잘하고 언굴도..헿  10     0     0
# 2                                       전우치역할만큼은 강동원이 최고   5     0     0
# 3      안티도 없고 알바도 없는 3년지난 지금 평점남깁니다.  이영화 만드시는데 고생하신분...  10     0     0
# 4              정말 재미있었고 즐기면서 봤다히어로 영화의 명작이제 ㅋㅋ너무 너무 짱이었다  10     0     0
# ...                                                  ...  ..   ...   ...
# ...

# %% [markdown]
# 여기부터

# %%
df_03클래식['작성일시']=pd.to_datetime(df_03클래식['작성일자'])

df_04이터널선샤인['작성일시']=pd.to_datetime(df_04이터널선샤인['작성일자'])
df_04태극기휘날리며['작성일시']=pd.to_datetime(df_04태극기휘날리며['작성일자'])
df_05왕의남자['작성일시']=pd.to_datetime(df_05왕의남자['작성일자'])
df_05찰리와초콜릿공장['작성일시']=pd.to_datetime(df_05찰리와초콜릿공장['작성일자'])

df_06라디오스타['작성일시']=pd.to_datetime(df_06라디오스타['작성일자'])
df_06미녀는괴로워['작성일시']=pd.to_datetime(df_06미녀는괴로워['작성일자'])
df_071번가의기적['작성일시']=pd.to_datetime(df_071번가의기적['작성일자'])
df_07밀양['작성일시']=pd.to_datetime(df_07밀양['작성일자'])

df_08다크나이트['작성일시']=pd.to_datetime(df_08다크나이트['작성일자'])
df_08말할수없는비밀['작성일시']=pd.to_datetime(df_08말할수없는비밀['작성일자'])
df_097급공무원['작성일시']=pd.to_datetime(df_097급공무원['작성일자'])
df_09전우치['작성일시']=pd.to_datetime(df_09전우치['작성일자'])

# %%
# date_string = '2010-12-31 23:59:59' 
# splittime = datetime.datetime.strptime('date_string', '%Y-%m-%d %H:%M:%S')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/qw/j72d9nwn5dq0vxtqtw2bbtnh0000gp/T/ipykernel_5688/2981343012.py in <module>
#       1 date_string = '2010-12-31'
# ----> 2 splittime = datetime.datetime.strptime('date_string', '%Y-%m-%d')
#
# ~/opt/anaconda3/lib/python3.9/_strptime.py in _strptime_datetime(cls, data_string, format)
#     566     """Return a class cls instance based on the input string and the
#     567     format string."""
# --> 568     tt, fraction, gmtoff_fraction = _strptime(data_string, format)
#     569     tzname, gmtoff = tt[-2:]
#     570     args = tt[:6] + (fraction,)
#
# ~/opt/anaconda3/lib/python3.9/_strptime.py in _strptime(data_string, format)
#     347     found = format_regex.match(data_string)
#     348     if not found:
# --> 349         raise ValueError("time data %r does not match format %r" %
# ...

# %%
df_03클래식.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10240 entries, 0 to 10239
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  10240 non-null  int64
#  1   댓글번호        10240 non-null  int64
#  2   작성일자        10240 non-null  object
#  3   댓글          9824 non-null   object
#  4   평점          10240 non-null  int64
#  5   관람여부        10240 non-null  int64
#  6   스포여부        10240 non-null  int64
#  7   공감수         10240 non-null  int64
#  8   비공감수        10240 non-null  int64
#  9   id          10240 non-null  object
#  10  작성일시        10240 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(7), object(3)
# memory usage: 880.1+ KB

# %%
df_03클래식["작성연도"] = df_03클래식["작성일자"].str[:4]

df_03클래식 = df_03클래식.drop(columns='Unnamed: 0')

# %%
df_04이터널선샤인["작성연도"] = df_04이터널선샤인["작성일자"].str[:4]
df_04태극기휘날리며["작성연도"] = df_04태극기휘날리며["작성일자"].str[:4]
df_05왕의남자["작성연도"] = df_05왕의남자["작성일자"].str[:4]
df_05찰리와초콜릿공장["작성연도"] = df_05찰리와초콜릿공장["작성일자"].str[:4]

df_06라디오스타["작성연도"] = df_06라디오스타["작성일자"].str[:4]
df_06미녀는괴로워["작성연도"] = df_06미녀는괴로워["작성일자"].str[:4]
df_071번가의기적["작성연도"] = df_071번가의기적["작성일자"].str[:4]
df_07밀양["작성연도"] = df_07밀양["작성일자"].str[:4]

df_08다크나이트["작성연도"] = df_08다크나이트["작성일자"].str[:4]
df_08말할수없는비밀["작성연도"] = df_08말할수없는비밀["작성일자"].str[:4]
df_097급공무원["작성연도"] = df_097급공무원["작성일자"].str[:4]
df_09전우치["작성연도"] = df_09전우치["작성일자"].str[:4]

# %%
# df_03클래식_div = df_03클래식[int(df_03클래식["작성연도"]) <=2010 ]

# df_04이터널선샤인_div = df_04이터널선샤인[int(df_04이터널선샤인["작성연도"]) <=2010 ]
# df_04태극기휘날리며_div = df_04태극기휘날리며[int(df_04태극기휘날리며["작성연도"]) <=2010 ]
# df_05왕의남자_div = df_05왕의남자[int(df_05왕의남자["작성연도"]) <=2010 ]
# df_05찰리와초콜릿공장_div = df_05찰리와초콜릿공장[int(df_05찰리와초콜릿공장["작성연도"]) <=2010 ]

# df_06라디오스타_div = df_06라디오스타[int(df_06라디오스타["작성연도"]) <=2010 ]
# df_06미녀는괴로워_div = df_06미녀는괴로워[int(df_06미녀는괴로워["작성연도"]) <=2010 ]
# df_071번가의기적_div = df_071번가의기적[int(df_071번가의기적["작성연도"]) <=2010 ]
# df_07밀양_div = df_07밀양[int(df_07밀양["작성연도"]) <=2010 ]

# df_08다크나이트_div = df_08다크나이트[int(df_08다크나이트["작성연도"]) <=2010 ]
# df_08말할수없는비밀_div = df_08말할수없는비밀[int(df_08말할수없는비밀["작성연도"]) <=2010 ]
# df_097급공무원_div = df_097급공무원[int(df_097급공무원["작성연도"]) <=2010 ]
# df_09전우치_div = df_09전우치[int(df_09전우치["작성연도"]) <=2010 ]

# df_09전우치_div
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/qw/j72d9nwn5dq0vxtqtw2bbtnh0000gp/T/ipykernel_5688/1904571581.py in <module>
# ----> 1 df_03클래식_div = df_03클래식[int(df_03클래식["작성연도"]) <=2010 ]
#       2
#       3 df_04이터널선샤인_div = df_04이터널선샤인[int(df_04이터널선샤인["작성연도"]) <=2010 ]
#       4 df_04태극기휘날리며_div = df_04태극기휘날리며[int(df_04태극기휘날리며["작성연도"]) <=2010 ]
#       5 df_05왕의남자_div = df_05왕의남자[int(df_05왕의남자["작성연도"]) <=2010 ]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in wrapper(self)
#     183         if len(self) == 1:
#     184             return converter(self.iloc[0])
# --> 185         raise TypeError(f"cannot convert the series to {converter}")
#     186
#     187     wrapper.__name__ = f"__{converter.__name__}__"
#
# TypeError: cannot convert the series to <class 'int'>

# %% [markdown]
# 여기까지 건너고

# %%
df_all = pd.concat([df_03클래식, df_04이터널선샤인])
df_all
# Out:
#           댓글번호              작성일자  \
# 0      7638100  2013.06.14 13:36
# 1      7504002  2013.05.03 21:02
# 2      7898800  2013.08.18 13:12
# 3      7573135  2013.06.02 18:05
# 4      7644959  2013.06.15 23:28
# ...        ...               ...
# 9753  12215087  2017.01.22 23:04
# 9754  12330861  2017.02.19 16:42
# 9755   9634376  2015.01.25 12:20
# 9756  14545277  2018.08.29 22:39
# 9757  12313176  2017.02.15 15:10
#
#                                                      댓글  평점  관람여부  스포여부   공감수  \
# 0     열번을 봐도 열번 다 재미있고 설레는 영화는 이것뿐인것 같아요비오고 흐리니까 또 떠...  10     0     0  3082
# 1       늑대소년?건축학개론?  다 필요없고 클래식이 지금 개봉했다면 멜로 흥행1위가 됬을거야  10     0     0  2984
# 2     조승우의 연기에 큰 박수를보내주고 싶다. 손예진을 바라보는 표정, 눈빛, 그리고 연...  10     0     0  2452
# 3     이 영화를 촌스러워 보인다는 현대의 시선으로 보지말자. 그 시대에선 이 얼마나 순수...  10     0     0  2456
# 4                                                명작오브명작  10     0     0  2200
# ...                                                 ...  ..   ...   ...   ...
# ...

# %%
df_all = pd.concat([df_04태극기휘날리며, df_05왕의남자, df_05찰리와초콜릿공장, df_06라디오스타, df_06미녀는괴로워, df_071번가의기적, df_07밀양, df_08다크나이트, df_08말할수없는비밀, df_097급공무원, df_09전우치])
df_all
# Out:
#            댓글번호              작성일자  \
# 0       7641243  2013.06.15 06:06
# 1       7586730  2013.06.05 23:51
# 2       7687574  2013.06.28 21:32
# 3       7684885  2013.06.27 23:16
# 4       7615983  2013.06.09 04:45
# ...         ...               ...
# 19815  17681548  2021.08.31 21:37
# 19816  15352589  2019.03.02 22:45
# 19817  10335633  2015.09.16 21:34
# 19818  17041091  2020.08.08 17:56
# 19819  16691431  2020.02.08 08:34
#
#                                                       댓글  평점  관람여부  스포여부  \
# 0      중학교때 처음보고 제일 많이 울었던 영화다. 9년이 지나고 대학을 졸업한 지금, 갑...  10     0     0
# 1                                           우리나라 영화 top5  10     0     0
# 2                                      말이필요없는 대작이다......  10     0     0
# 3                                              감동의 대작 ㅠㅠ  10     0     0
# 4                           언제봐도 최고 요즘 천만관객 영화보다 훨씬 뛰어나다  10     0     0
# ...                                                  ...  ..   ...   ...
# ...

# %%
df_all["작성연도"] = df_all["작성연도"].astype(int)
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 180550 entries, 0 to 19819
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   댓글번호    180550 non-null  int64
#  1   작성일자    180550 non-null  object
#  2   댓글      179890 non-null  object
#  3   평점      180550 non-null  int64
#  4   관람여부    180550 non-null  int64
#  5   스포여부    180550 non-null  int64
#  6   공감수     180550 non-null  int64
#  7   비공감수    180550 non-null  int64
#  8   id      180550 non-null  object
#  9   작성일시    180550 non-null  datetime64[ns]
#  10  작성연도    180550 non-null  int64
#  11  영화제목    180550 non-null  object
# dtypes: datetime64[ns](1), int64(7), object(4)
# memory usage: 17.9+ MB

# %% [markdown]
# 여기까지는 다시입히는데 오래걸렸다.

# %%
df_all_div = df_all[(df_all["작성연도"] < 2011)]
df_all_div
# Out:
#           댓글번호              작성일자                                     댓글  평점  \
# 127     460558  2005.10.31 16:32    실화라서 너무 아프고 속상하고,영화로써 즐길 수 없었으므로...   1
# 242     239049  2005.03.12 07:53                 곰곰히 생각해봐라.이야기가 연결되는지..   1
# 696     205139  2005.02.03 00:54           정말 재미없다..... 이게 왜 뜨는지 모르겠다..   1
# 923     748824  2006.04.04 23:26                        난 정말 이 영화가 싫어요.   1
# 924     706828  2006.03.06 14:34                                   글쎄..   1
# ...        ...               ...                                    ...  ..
# 19450  4047931  2009.12.16 18:15        강동원, 김윤석, 임수정, 유해진인데 무슨 말이 필요해?  10
# 19451  4047930  2009.12.16 18:15        흥미진진....한국오락영화의 신기원 ..새롭게..간다..  10
# 19452  4047887  2009.12.16 17:54                           완전 웃김 대박추천!!  10
# 19453  4047849  2009.12.16 17:34             0점은없나 ㅋ 예고편, 시놉시스 딱봐도 유치찬란   1
# 19662  4209750  2010.01.25 23:10  지난 5년간 최악의 영화라 손꼽을듯. 초등학생용.. 보는내내 짜증만   1
#
# ...

# %% [markdown]
# 영화 비율이 어떻게 되려나?

# %%
df_all_div.pivot_table(index="영화제목", aggfunc="count")['id']
# Out:
# 영화제목
# 1번가의_기적        4012
# 7급공무원          8624
# 다크나이트         19045
# 라디오스타          9688
# 말할_수_없는_비밀    31804
# 미녀는_괴로워       14930
# 밀양             3681
# 왕의_남자         32329
# 전우치           17635
# 찰리와_초콜릿_공장     3905
# 태극기_휘날리며       7556
# Name: id, dtype: int64

# %%
df_all_div_sample = df_all_div.sample(50000)
df_all_div_sample
# Out:
#           댓글번호              작성일자                                         댓글  \
# 9474    642518  2006.02.02 17:22                       아 완전 멋지다 ㅋㅋㅋ 디비디 살까봐
# 1245   2431806  2008.02.10 14:54               최곤의 매니저 박민수의 인생을 생각하면 너무 슬프다
# 6669    101185  2004.09.02 01:59   한국 영화의 더 나은 발전을 보여주는 작품... 다만 어딘가 조금 아쉬움
# 21661  2852057  2008.08.08 21:03  2008최고의 영화인듯..특히 조커가 정말정말 인상적이었다ㅠㅠㅠㅠ대박입니다
# 9242   4150055  2010.01.09 03:44                                   볼만 하던데;;
# ...        ...               ...                                        ...
# 6595   4182586  2010.01.18 09:50                             재미있어요.짱!짱!짱!짱!
# 6822   1356949  2007.01.04 19:24                    재밌습니다 ~김아중 아주 귀엽더군요 ~ ㅋ
# 7693   1172754  2006.10.09 09:04                     자연스런 감동에 이동.. 괜찮은영화였다.
# 1782   2330938  2008.01.14 19:54                                  재미잇어요 ~~~
# 5028   5047952  2010.12.12 18:07                               중국인이 이럴수 없다.
#
# ...

# %%
# !pip install Spacing
# Out:
# ERROR: Could not find a version that satisfies the requirement Spacing (from versions: none)
# ERROR: No matching distribution found for Spacing

# %%
from pykospacing import Spacing
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/qw/j72d9nwn5dq0vxtqtw2bbtnh0000gp/T/ipykernel_5688/1372752084.py in <module>
# ----> 1 from pykospacing import Spacing
#
# ModuleNotFoundError: No module named 'pykospacing'

# %%
before_2010_review_list = [] 

for i in range(len(df_all_div_sample['댓글'])):
    before_2010_review_list.append(spacing(df_all_div_sample['댓글'][i]))

# %%
df_drama['댓글']=df_drama['댓글'].str.replace('[^ㄱ-ㅎ ㅏ-ㅣ 가-힣]','')

# %%
spacing=Spacing()

# %%
import konlpy

# %%
from konlpy.tag import *

hannanum = Hannanum()
kkma = Kkma()
komoran = Komoran()
okt = Okt()
mecab = Mecab()

# %% [markdown]
# nouns : 명사 추출
# morphs : 형태소 추출
# pos : 품사 부착
